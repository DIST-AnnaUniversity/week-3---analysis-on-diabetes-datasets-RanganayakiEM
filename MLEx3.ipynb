# %%
import pandas as pd
df = pd.read_csv('data-44', sep='\t')

# %%
df
# Out:
#            Date   Time  code  value
# 0    08-26-1990  17:26    62    204
# 1    08-26-1990  17:29    33      5
# 2    08-26-1990  17:29    34      4
# 3    08-26-1990  20:33    63    254
# 4    08-26-1990  20:35    33      3
# ..          ...    ...   ...    ...
# 294  09-25-1990  12:08    33      3
# 295  09-25-1990  15:49    64     56
# 296  09-25-1990  20:05    63    327
# 297  09-25-1990  20:07    33      5
# 298  09-25-1990  20:07    35      6
#
# [299 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'code', 'value'], dtype='object')

# %%
newdf= (
    df.pivot_table(index=df.groupby('code').cumcount(),
                   columns='code',
                   values='value')
        .add_prefix('')
        .rename_axis(columns=None)
)

# %%
newdf
# Out:
#       33    34    35    57     58     60     61     62     63     64   65   72
# 0    5.0   4.0  17.0  36.0  267.0  334.0  243.0  204.0  254.0  208.0  0.0  0.0
# 1    3.0   6.0   3.0  50.0   91.0  269.0    NaN   85.0   82.0  142.0  0.0  0.0
# 2    3.0  17.0   6.0  45.0  265.0   51.0    NaN  192.0  288.0   59.0  0.0  NaN
# 3    4.0   4.0  17.0  43.0  246.0  251.0    NaN  224.0   94.0   65.0  0.0  NaN
# 4    2.0   6.0   3.0  45.0   89.0  141.0    NaN  168.0   45.0   56.0  0.0  NaN
# ..   ...   ...   ...   ...    ...    ...    ...    ...    ...    ...  ...  ...
# 99   4.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN  NaN  NaN
# 100  2.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN  NaN  NaN
# 101  4.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN  NaN  NaN
# 102  3.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN  NaN  NaN
# 103  5.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN  NaN  NaN
#
# [104 rows x 12 columns]

# %%
newdf = newdf[['33','34','35', '57', '58','60','62', '63']]
newdf
# Out:
#       33    34    35    57     58     60     62     63
# 0    5.0   4.0  17.0  36.0  267.0  334.0  204.0  254.0
# 1    3.0   6.0   3.0  50.0   91.0  269.0   85.0   82.0
# 2    3.0  17.0   6.0  45.0  265.0   51.0  192.0  288.0
# 3    4.0   4.0  17.0  43.0  246.0  251.0  224.0   94.0
# 4    2.0   6.0   3.0  45.0   89.0  141.0  168.0   45.0
# ..   ...   ...   ...   ...    ...    ...    ...    ...
# 99   4.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 100  2.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 101  4.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 102  3.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 103  5.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN
#
# [104 rows x 8 columns]

# %%
newdf = newdf.rename(columns={'33': 'Regular insulin dose', '34': 'NPH insulin dose', '35' : 'UltraLente insulin dose', 
                        '57': 'Unspecified blood glucose measurement', '58':'Pre-breakfast blood glucose measurement',
                        '60':'Pre-lunch blood glucose measurement',
                        '62':'Pre-supper blood glucose measurement', '63' : 'Post-supper blood glucose measurement'
                        })

# %%
newdf
# Out:
#      Regular insulin dose  NPH insulin dose  UltraLente insulin dose  \
# 0                     5.0               4.0                     17.0
# 1                     3.0               6.0                      3.0
# 2                     3.0              17.0                      6.0
# 3                     4.0               4.0                     17.0
# 4                     2.0               6.0                      3.0
# ..                    ...               ...                      ...
# 99                    4.0               NaN                      NaN
# 100                   2.0               NaN                      NaN
# 101                   4.0               NaN                      NaN
# 102                   3.0               NaN                      NaN
# 103                   5.0               NaN                      NaN
#
#      Unspecified blood glucose measurement  \
# 0                                     36.0
# 1                                     50.0
# ...

# %%
newdf.head()
# Out:
#    Regular insulin dose  NPH insulin dose  UltraLente insulin dose  \
# 0                   5.0               4.0                     17.0
# 1                   3.0               6.0                      3.0
# 2                   3.0              17.0                      6.0
# 3                   4.0               4.0                     17.0
# 4                   2.0               6.0                      3.0
#
#    Unspecified blood glucose measurement  \
# 0                                   36.0
# 1                                   50.0
# 2                                   45.0
# 3                                   43.0
# 4                                   45.0
#
#    Pre-breakfast blood glucose measurement  \
# 0                                    267.0
# 1                                     91.0
# 2                                    265.0
# 3                                    246.0
# 4                                     89.0
#
# ...

# %%
newdf.mean()
# Out:
# Regular insulin dose                         3.307692
# NPH insulin dose                             8.728814
# UltraLente insulin dose                      9.000000
# Unspecified blood glucose measurement       80.700000
# Pre-breakfast blood glucose measurement    180.142857
# Pre-lunch blood glucose measurement        178.916667
# Pre-supper blood glucose measurement       166.115385
# Post-supper blood glucose measurement      191.571429
# dtype: float64

# %%
newdf.median()
# Out:
# Regular insulin dose                         3.0
# NPH insulin dose                             6.0
# UltraLente insulin dose                      6.0
# Unspecified blood glucose measurement       45.5
# Pre-breakfast blood glucose measurement    190.5
# Pre-lunch blood glucose measurement        162.0
# Pre-supper blood glucose measurement       176.5
# Post-supper blood glucose measurement      246.0
# dtype: float64

# %%
from collections import Counter

for col in newdf:
  print(col, end="\t")
  c = Counter(newdf[col])
  print(c.most_common(1)[0][0])
# Out:
# Regular insulin dose	3.0
# NPH insulin dose	17.0
# UltraLente insulin dose	17.0
# Unspecified blood glucose measurement	45.0
# Pre-breakfast blood glucose measurement	91.0
# Pre-lunch blood glucose measurement	141.0
# Pre-supper blood glucose measurement	224.0
# Post-supper blood glucose measurement	254.0

# %%
newdf.var()
# Out:
# Regular insulin dose                           1.593727
# NPH insulin dose                              37.063121
# UltraLente insulin dose                       39.000000
# Unspecified blood glucose measurement       4312.011111
# Pre-breakfast blood glucose measurement     5998.645503
# Pre-lunch blood glucose measurement        13179.174242
# Pre-supper blood glucose measurement        6559.466154
# Post-supper blood glucose measurement       8357.857143
# dtype: float64

# %%
newdf.std()
# Out:
# Regular insulin dose                         1.262429
# NPH insulin dose                             6.087949
# UltraLente insulin dose                      6.244998
# Unspecified blood glucose measurement       65.665905
# Pre-breakfast blood glucose measurement     77.450923
# Pre-lunch blood glucose measurement        114.800585
# Pre-supper blood glucose measurement        80.990531
# Post-supper blood glucose measurement       91.421317
# dtype: float64

# %%
newdf.cov()
# Out:
#                                          Regular insulin dose  \
# Regular insulin dose                                 1.593727
# NPH insulin dose                                     1.287843
# UltraLente insulin dose                             -1.666667
# Unspecified blood glucose measurement              -31.344444
# Pre-breakfast blood glucose measurement            -25.280423
# Pre-lunch blood glucose measurement                 60.507576
# Pre-supper blood glucose measurement                -1.980000
# Post-supper blood glucose measurement               15.285714
#
#                                          NPH insulin dose  \
# Regular insulin dose                             1.287843
# NPH insulin dose                                37.063121
# UltraLente insulin dose                        -20.875000
# Unspecified blood glucose measurement         -185.977778
# Pre-breakfast blood glucose measurement        -71.555556
# ...

# %%
import seaborn as sb

# %%
newdf.boxplot()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
import numpy as np
for col in newdf:
  data = newdf[col]
  data.dropna(inplace=True)
  np.sort(data)
  Q1 = np.percentile(data, 25, interpolation = 'midpoint')
  Q3 = np.percentile(data, 75, interpolation = 'midpoint')
  IQR = Q3 - Q1
  IQR
  lower_bound = Q1 - (1.5 * IQR) 
  upper_bound = Q3 + (1.5 * IQR) 
  print("\n", col)
  print('Q1',Q1)
  print('Q3',Q3)
  print('IQR',IQR)
  print('Upper bound',upper_bound)
  print('lower_bound',lower_bound)
# Out:
#  Regular insulin dose
# Q1 2.0
# Q3 4.0
# IQR 2.0
# Upper bound 7.0
# lower_bound -1.0
#
#  NPH insulin dose
# Q1 3.0
# Q3 17.0
# IQR 14.0
# Upper bound 38.0
# lower_bound -18.0
#
#  UltraLente insulin dose
# Q1 3.0
# Q3 17.0
# IQR 14.0
# Upper bound 38.0
# lower_bound -18.0
#
#  Unspecified blood glucose measurement
# Q1 44.0
# Q3 79.0
# IQR 35.0
# Upper bound 131.5
# lower_bound -8.5
#
#  Pre-breakfast blood glucose measurement
# Q1 101.0
# Q3 246.5
# IQR 145.5
# Upper bound 464.75
# lower_bound -117.25
#
#  Pre-lunch blood glucose measurement
# Q1 67.0
# Q3 260.0
# IQR 193.0
# Upper bound 549.5
# lower_bound -222.5
#
#  Pre-supper blood glucose measurement
# Q1 84.5
# Q3 224.0
# IQR 139.5
# Upper bound 433.25
# lower_bound -124.75
#
#  Post-supper blood glucose measurement
# Q1 100.0
# Q3 269.0
# IQR 169.0
# Upper bound 522.5
# lower_bound -153.5

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Regular insulin dose                     104 non-null    float64
#  1   NPH insulin dose                         59 non-null     float64
#  2   UltraLente insulin dose                  25 non-null     float64
#  3   Unspecified blood glucose measurement    10 non-null     float64
#  4   Pre-breakfast blood glucose measurement  28 non-null     float64
#  5   Pre-lunch blood glucose measurement      12 non-null     float64
#  6   Pre-supper blood glucose measurement     26 non-null     float64
#  7   Post-supper blood glucose measurement    21 non-null     float64
# dtypes: float64(8)
# memory usage: 7.3 KB

# %%
df_wo_na = newdf[:10]

# %%
df_wo_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Regular insulin dose                     10 non-null     float64
#  1   NPH insulin dose                         10 non-null     float64
#  2   UltraLente insulin dose                  10 non-null     float64
#  3   Unspecified blood glucose measurement    10 non-null     float64
#  4   Pre-breakfast blood glucose measurement  10 non-null     float64
#  5   Pre-lunch blood glucose measurement      10 non-null     float64
#  6   Pre-supper blood glucose measurement     10 non-null     float64
#  7   Post-supper blood glucose measurement    10 non-null     float64
# dtypes: float64(8)
# memory usage: 720.0 bytes

# %%
sb.pairplot(df_wo_na,kind='scatter')

# %%
sb.heatmap(df_wo_na.corr(), cmap='coolwarm',annot=True)

# %%
import matplotlib.pyplot as plt
x = (df_wo_na['Pre-breakfast blood glucose measurement'])
y = (df_wo_na['Pre-lunch blood glucose measurement'])
x = x[:12]
y = y[:12]
plt.scatter(x, y,color='blue')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
X = x.values.reshape(-1, 1)
Y = x.values.reshape(-1, 1)
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %%
#plt.scatter(X, Y)
plt.scatter(x, y,color='blue')
plt.plot(X, Y_pred, color='red')
plt.show()
